# %% [markdown]
# <a href="https://colab.research.google.com/github/RajShekhar0341/TUTEDUDE-ASSIGNMENTS/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1

# %%
num_one = int(input("Enter first no"))
num_two = int(input("Enter second no"))

addition = num_one + num_two
subtration = num_one - num_two
multiplication = num_one * num_two
division = num_one / num_two
print(addition)
print(subtration)
print(multiplication)
print(division)
# Out:
# Enter first no100
# Enter second no50
# 150
# 50
# 5000
# 2.0

# %% [markdown]
# Task 2

# %%
f_name = str(input("enter your first name"))
l_name = str(input("enter your last name"))

full_name = f_name + " " + l_name
print(f"Hello good moring {full_name}")
# Out:
# enter your first nameRaj
# enter your last nameShekhar
# Hello good moring Raj Shekhar

# %%
number = int(input("Enter your no"))

if number % 2 == 0:
    print(f"{number}: is an even")
elif number % 2 != 0:
    print(f"{number}: is an odd")
# Out:
# Enter your no7
# 7: is an odd

# %%
total_sum = 0

for num in range(1,50):
  total_sum += num
  if total_sum % 2 == 0:
    print(total_sum)
# Out:
# 6
# 10
# 28
# 36
# 66
# 78
# 120
# 136
# 190
# 210
# 276
# 300
# 378
# 406
# 496
# 528
# 630
# 666
# 780
# 820
# 946
# 990
# 1128
# 1176
